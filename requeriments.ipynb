# %%
# !pip install --dry-run 'numpy<2.1' numba --no-cache-dir
# !pip install numpy
# !pip install torch
# !pip install tqdm
# !pip install more-itertools
# !pip install tiktoken
# !pip install triton>=2.0.0;platform_machine=="x86_64" and sys_platform=="linux" or sys_platform=="linux2"
# !pip install git+https://github.com/openai/whisper.git

# %%
# !pip install setuptools-rust
# !pip install ffmpeg
# !pip install pydub

# %%
# !pip install mlx mlx-whisper

# %%
# !pip install whisperx

# %%
# !pip install --upgrade ipywidgets jupyter

# %%
# !pip uninstall torch
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# %%
# !pip install yt_dlp

# %%
# !pip install openai

# %%
# !pip install diffusers transformers accelerate
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu

# %%
# !pip install google-api-python-client pytz

# %%
####################################################
####################################################
####################################################
## nuevo entorno

# %%
# !pip install -U mlx-vlm mlx-audio

# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.4 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install PyPDF2
# !pip install requests
# !pip install openai
# !pip install yt_dlp
# !pip install google-api-python-client pytz

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 7.1 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
